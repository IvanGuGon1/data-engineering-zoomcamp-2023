# %%
import pandas as pd
import os
import yaml

# %%
df1 = pd.read_parquet('fhv_tripdata_2019-12.parquet')

# %%
df2 = pd.read_parquet('fhv_tripdata_2020-01.parquet')

# %%
df1.dtypes
# Out:
# dispatching_base_num              string
# pickup_datetime           datetime64[ns]
# dropOff_datetime          datetime64[ns]
# PUlocationID                       Int64
# DOlocationID                       Int64
# SR_Flag                            Int64
# Affiliated_base_number            object
# dtype: object

# %%
df2.dtypes
# Out:
# dispatching_base_num              object
# pickup_datetime           datetime64[ns]
# dropOff_datetime          datetime64[ns]
# PUlocationID                     float64
# DOlocationID                     float64
# SR_Flag                           object
# Affiliated_base_number            object
# dtype: object

# %%
df3 = pd.read_parquet('fhv_tripdata_2020-01.parquet').astype(df1.dtypes)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df3 = pd.read_parquet('fhv_tripdata_2020-01.parquet').astype(df1.dtypes)
#
# File ~/miniconda3/envs/zoomcamp2/lib/python3.9/site-packages/pandas/core/generic.py:6212, in NDFrame.astype(self, dtype, copy, errors)
#    6210 for col_name in dtype_ser.index:
#    6211     if col_name not in self:
# -> 6212         raise KeyError(
#    6213             "Only a column name can be used for the "
#    6214             "key in a dtype mappings argument. "
#    6215             f"'{col_name}' not found in columns."
#    6216         )
#    6218 dtype_ser = dtype_ser.reindex(self.columns, fill_value=None, copy=False)
#    6220 results = []
#
# KeyError: "Only a column name can be used for the key in a dtype mappings argument. 'VendorID' not found in columns."

# %%
df3.head()
df3.dtypes

# %%
files = os.listdir()
for file in files:
    if 'fhv_tripdata_2020' in file and 'parquet' in file:
        df = pd.read_parquet(file).astype(df1.dtypes)
        df.to_parquet(file,index=False)

# %%
df1 = pd.read_parquet('green_tripdata_2019-01.parquet')
df1.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2018-12-21 15:17:29   2018-12-21 15:18:57                  N
# 1         2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2         2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3         2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 4         2  2019-01-01 00:19:06   2019-01-01 00:39:43                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1           264           264                5           0.00
# 1           1            97            49                2           0.86
# 2           1            49           189                2           0.66
# 3           1           189            17                2           2.68
# 4           1            82           258                1           4.53
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
df2 = pd.read_parquet('green_tripdata_2020-01.parquet')
df2.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0       2.0  2019-12-18 15:52:30   2019-12-18 15:54:39                  N
# 1       2.0  2020-01-01 00:45:58   2020-01-01 00:56:39                  N
# 2       2.0  2020-01-01 00:41:38   2020-01-01 00:52:49                  N
# 3       1.0  2020-01-01 00:52:46   2020-01-01 01:14:21                  N
# 4       1.0  2020-01-01 00:19:57   2020-01-01 00:30:56                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0           264           264              5.0           0.00
# 1         5.0            66            65              2.0           1.28
# 2         1.0           181           228              1.0           2.47
# 3         1.0           129           263              2.0           6.30
# 4         1.0           210           150              1.0           2.30
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...
